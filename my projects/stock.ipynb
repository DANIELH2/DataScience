# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib nbagg

import seaborn as sns

# %%
df = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\test661.csv', index_col='date', parse_dates=True)
df.head()
# Out:
#                    1        2       3         4        13        33        41  \
# date
# 2019-01-01  1028.740  1053.67  37.160  1519.040  2141.005  1836.420  1147.450
# 2019-01-02  1029.650  1054.58  37.700  1526.615  2148.235  1840.405  1146.035
# 2019-01-03  1022.690  1047.42  36.980  1532.465  2123.845  1800.275  1131.725
# 2019-01-06  1030.925  1055.87  36.950  1540.220  2134.530  1790.475  1130.090
# 2019-01-07  1043.585  1068.87  37.145  1545.000  2156.555  1804.890  1140.845
#
#                  61        73        97  ...  1168186  1168533  1168558  \
# date                                     ...
# 2019-01-01  905.120  1711.335  3391.195  ...      NaN      NaN      NaN
# 2019-01-02  904.380  1710.130  3373.465  ...      NaN      NaN      NaN
# 2019-01-03  892.585  1693.245  3331.430  ...      NaN      NaN      NaN
# 2019-01-06  890.990  1700.915  3365.170  ...      NaN      NaN      NaN
# 2019-01-07  897.625  1717.285  3408.180  ...      NaN      NaN      NaN
#
# ...

# %%
df.shape
# Out:
# (447, 573)

# %%
df.dtypes
# Out:
# 1          float64
# 2          float64
# 3          float64
# 4          float64
# 13         float64
#             ...
# 1210152    float64
# 1820083    float64
# 2590248    float64
# 5010129    float64
# 5550157    float64
# Length: 573, dtype: object

# %%
df.describe()
# Out:
#              0         1         2         3         4         5         6   \
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   0.528391  0.470465  0.523434  0.512179  0.261863  0.349648  0.402157
# std    0.337836  0.324180  0.211797  0.316540  0.232599  0.244846  0.294270
# min    0.207350  0.047855  0.224327  0.035242  0.033500  0.052116  0.049433
# 25%    0.243239  0.287638  0.390875  0.338240  0.073147  0.213857  0.159635
# 50%    0.348430  0.406363  0.465017  0.438049  0.204960  0.255170  0.450015
# 75%    0.863272  0.646853  0.708999  0.745647  0.392871  0.460381  0.586331
# max    0.929934  0.970052  0.774943  0.944187  0.662543  0.791776  0.823715
#
#              7         8         9         10        11        12        13  \
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   0.628462  0.446448  0.396960  0.596627  0.374756  0.676362  0.677423
# ...

# %%
df1=df[["137","604611","662577","1130699","629014","273011","691212","281014","1081124","695437","1082379"]]
df1.head()
# Out:
#                  137  604611  662577  1130699  629014  273011  691212  281014  \
# date
# 2019-01-01  1341.040  2284.0  2389.5    14555  5829.0   40395  1170.5  2125.0
# 2019-01-02  1341.550  2289.0  2401.0    14665  5794.0   40485  1176.0  2105.0
# 2019-01-03  1327.180  2259.0  2381.5    14850  5963.0   39660  1156.5  2070.0
# 2019-01-06  1333.550  2274.0  2392.0    15265  6291.0   39450  1154.5  2090.0
# 2019-01-07  1350.075  2293.5  2410.5    15800  6477.0   39785  1163.0  2117.5
#
#             1081124  695437  1082379
# date
# 2019-01-01    42940  6360.0   5555.0
# 2019-01-02    42860  6368.5   5496.5
# 2019-01-03    43030  6309.5   5370.5
# 2019-01-06    43920  6369.5   5284.5
# 2019-01-07    44860  6495.5   5327.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#df = pd.DataFrame(np.random.rand(7,20))

df1.plot(subplots=True, layout=(6,2), figsize=(10,10))

plt.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.2593298494784">

# %%
plt.figure(figsize=(10,4))
plt.plot(df1, label='Average Price 125')
# Out:
# <img src="data:image/png;base64,..." width="999.2593298494784">
# ...
