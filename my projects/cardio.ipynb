# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
# Out:
# C:\Users\DANIEL\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## level_2

# %%
df = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\level_2.csv')
df.head()
# Out:
#   Row Labels    C01     C02       C03   C04   C05     C07     C08     C09  \
# 0   1/1/2016  26304   28215   61790.0  1330  1580  166417   98143  285936
# 1   1/2/2016   5649    5090   14435.0    60   156   34813   19275   60981
# 2   1/3/2016  90339  110821  222132.0  6260  5173  543494  340190  881305
# 3   1/4/2016  87310   90085  189066.0  4560  4357  468631  292724  768213
# 4   1/5/2016  78227   88597  191117.0  5300  3895  473784  288829  772596
#
#       C10  Year  Month
# 0  273621  2016      1
# 1   62928  2016      1
# 2  843468  2016      1
# 3  725303  2016      1
# 4  728361  2016      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Row Labels  1770 non-null   object
#  1   C01         1770 non-null   int64
#  2   C02         1770 non-null   int64
#  3   C03         1770 non-null   float64
#  4   C04         1770 non-null   int64
#  5   C05         1770 non-null   int64
#  6   C07         1770 non-null   int64
#  7   C08         1770 non-null   int64
#  8   C09         1770 non-null   int64
#  9   C10         1770 non-null   int64
#  10  Year        1770 non-null   int64
#  11  Month       1770 non-null   int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 166.1+ KB

# %%
list(df.columns.values)
# Out:
# ['Row Labels',
#  'C01',
#  'C02',
#  'C03',
#  'C04',
#  'C05',
#  'C07',
#  'C08',
#  'C09',
#  'C10',
#  'Year',
#  'Month']

# %%
import math
cols_plot = ['C01','C02','C03','C07','C09','C10']
dfatc_365d = df[cols_plot].rolling(window=365, center=True).mean()
dfatc_30d = df[cols_plot].rolling(30, center=True).mean()
dfatc_std = df[cols_plot].rolling(30, center=True).std()
subplotindex=0
numrows=3
numcols=2
fig, ax = plt.subplots(numrows, numcols, figsize=(18, 12))
plt.subplots_adjust(wspace=0.1, hspace=0.3)
for x in cols_plot:
    rowindex=math.floor(subplotindex/numcols)
    colindex=subplotindex-(rowindex*numcols)
    ax[rowindex,colindex].plot(df.loc[:,x], linewidth=0.5, label='Daily sales')
    ax[rowindex,colindex].plot(dfatc_30d.loc[:,x], label='30-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_365d.loc[:,x], color='0.2', linewidth=3, label='365-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_std.loc[:,x], color='0.5', linewidth=3, label='30-d Rolling Std')
    ax[rowindex,colindex].set_ylabel('Sales')
    ax[rowindex,colindex].legend()
    ax[rowindex,colindex].set_title('Trends in '+x+' drugs sales');   
    subplotindex=subplotindex+1
plt.show()

# %% [markdown]
# ## level_3

# %%
import pandas as pd

# %%
df2 = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\level_3.csv')
df2.head()
# Out:
#   Row Labels    C01A     C01B   C01C     C01D  C01E     C02A     C02C    C02D  \
# 0   1/1/2016  1168.0  16575.0  126.0   8435.0   0.0   5105.0  21750.0  1270.0
# 1   1/2/2016   121.0   3960.0    3.0   1565.0   0.0   1000.0   4040.0    50.0
# 2   1/3/2016  4475.0  51988.0  794.0  33082.0   0.0  23829.0  82107.0  4465.0
# 3   1/4/2016  4209.0  51201.0  322.0  31578.0   0.0  20350.0  64595.0  4660.0
# 4   1/5/2016  3207.0  46495.0  820.0  27677.0  28.0  19300.0  64427.0  4150.0
#
#     C02K  ...      C07A      C08C     C08D      C09A     C09B      C09C  \
# 0   90.0  ...  166417.0   91928.0   6215.0  165077.0  30038.0   57937.0
# 1    0.0  ...   34813.0   18095.0   1180.0   35172.0   6874.0   11361.0
# 2  420.0  ...  543494.0  318370.0  21820.0  484229.0  82506.0  209897.0
# 3  480.0  ...  468631.0  268489.0  24235.0  422265.0  70220.0  181296.0
# 4  720.0  ...  473784.0  265404.0  23425.0  422425.0  72771.0  176689.0
#
#        C09D   C09X      C10A  C10B
# 0   32884.0    0.0  273621.0   0.0
# 1    7574.0    0.0   62928.0   0.0
# 2  104589.0   84.0  843468.0   0.0
# 3   94236.0  196.0  725303.0   0.0
# 4  100627.0   84.0  728361.0   0.0
#
# [5 rows x 29 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Row Labels  1770 non-null   object
#  1   C01A        1770 non-null   float64
#  2   C01B        1770 non-null   float64
#  3   C01C        1770 non-null   float64
#  4   C01D        1770 non-null   float64
#  5   C01E        1770 non-null   float64
#  6   C02A        1770 non-null   float64
#  7   C02C        1770 non-null   float64
#  8   C02D        1770 non-null   float64
#  9   C02K        1770 non-null   float64
#  10  C03A        1770 non-null   float64
#  11  C03B        1770 non-null   float64
#  12  C03C        1770 non-null   float64
#  13  C03D        1770 non-null   float64
#  14  C03E        1770 non-null   float64
#  15  C04A        1770 non-null   float64
#  16  C05A        1770 non-null   float64
#  17  C05B        1770 non-null   float64
#  18  C05C        1770 non-null   float64
#  19  C07A        1770 non-null   float64
#  20  C08C        1770 non-null   float64
#  21  C08D        1770 non-null   float64
#  22  C09A        1770 non-null   float64
#  23  C09B        1770 non-null   float64
#  24  C09C        1770 non-null   float64
#  25  C09D        1770 non-null   float64
#  26  C09X        1770 non-null   float64
#  27  C10A        1770 non-null   float64
#  28  C10B        1770 non-null   float64
# dtypes: float64(28), object(1)
# memory usage: 401.1+ KB

# %%
list(df2.columns.values)
# Out:
# ['Row Labels',
#  'C01A',
#  'C01B',
#  'C01C',
#  'C01D',
#  'C01E',
#  'C02A',
#  'C02C',
#  'C02D',
#  'C02K',
#  'C03A',
#  'C03B',
#  'C03C',
#  'C03D',
#  'C03E',
#  'C04A',
#  'C05A',
#  'C05B',
#  'C05C',
#  'C07A',
#  'C08C',
#  'C08D',
#  'C09A',
#  'C09B',
#  'C09C',
#  'C09D',
#  'C09X',
#  'C10A',
#  'C10B']

# %%
import math
cols_plot = ['C01C','C02K','C03C','C07A','C09A','C10A',] 
dfatc_365d = df2[cols_plot].rolling(window=365, center=True).mean()
dfatc_30d = df2[cols_plot].rolling(30, center=True).mean()
dfatc_std = df2[cols_plot].rolling(30, center=True).std()
subplotindex=0
numrows=3
numcols=2
fig, ax = plt.subplots(numrows, numcols, figsize=(18, 12))
plt.subplots_adjust(wspace=0.1, hspace=0.3)
for x in cols_plot:
    rowindex=math.floor(subplotindex/numcols)
    colindex=subplotindex-(rowindex*numcols)
    ax[rowindex,colindex].plot(df2.loc[:,x], linewidth=0.5, label='Daily sales')
    ax[rowindex,colindex].plot(dfatc_30d.loc[:,x], label='30-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_365d.loc[:,x], color='0.2', linewidth=3, label='365-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_std.loc[:,x], color='0.5', linewidth=3, label='30-d Rolling Std')
    ax[rowindex,colindex].set_ylabel('Sales')
    ax[rowindex,colindex].legend()
    ax[rowindex,colindex].set_title('Trends in '+x+' drugs sales');   
    subplotindex=subplotindex+1
plt.show()

# %% [markdown]
# ## level_4

# %%
df3 = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\level_4.csv')
df3.head()
# Out:
#   Row Labels   C01AA   C01BA  C01BB    C01BC    C01BD  C01CA  C01CE    C01DA  \
# 0   1/1/2016  1168.0   210.0  100.0  11250.0   5015.0  126.0    0.0   8435.0
# 1   1/2/2016   121.0   390.0    0.0   1860.0   1710.0    3.0    0.0   1565.0
# 2   1/3/2016  4475.0   990.0  100.0  33663.0  17235.0  794.0    0.0  33082.0
# 3   1/4/2016  4209.0  1140.0  100.0  34353.0  15608.0  322.0    0.0  31578.0
# 4   1/5/2016  3207.0  1440.0  300.0  27360.0  17395.0  820.0    0.0  27677.0
#
#    C01EA  ...    C09DA    C09DB  C09DX  C09XA   C10AA    C10AB  C10AC  C10AD  \
# 0    0.0  ...  15947.0  16937.0    0.0    0.0  247430  16530.0    0.0    0.0
# 1    0.0  ...   3480.0   4094.0    0.0    0.0   56244   4960.0  100.0    0.0
# 2    0.0  ...  59003.0  45586.0    0.0   84.0  767459  46221.0  456.0   90.0
# 3    0.0  ...  54258.0  39978.0    0.0  196.0  660892  39550.0  621.0   90.0
# 4    0.0  ...  61432.0  39195.0    0.0   84.0  663881  39920.0  351.0  360.0
#
#      C10AX  C10BA
# 0   9661.0    0.0
# 1   1624.0    0.0
# 2  29242.0    0.0
# 3  24150.0    0.0
# 4  23849.0    0.0
#
# [5 rows x 52 columns]

# %%
list(df3.columns.values)
# Out:
# ['Row Labels',
#  'C01AA',
#  'C01BA',
#  'C01BB',
#  'C01BC',
#  'C01BD',
#  'C01CA',
#  'C01CE',
#  'C01DA',
#  'C01EA',
#  'C01EB',
#  'C02AB',
#  'C02AC',
#  'C02CA',
#  'C02DB',
#  'C02DC',
#  'C02KX',
#  'C03AA',
#  'C03BA',
#  'C03CA',
#  'C03DA',
#  'C03DB',
#  'C03EA',
#  'C04AB',
#  'C04AC',
#  'C04AD',
#  'C04AX',
#  'C05AA',
#  'C05AE',
#  'C05AX',
#  'C05BB',
#  'C05CA',
#  'C07AA',
#  'C07AB',
#  'C07AG',
#  'C08CA',
#  'C08DA',
#  'C08DB',
#  'C09AA',
#  'C09BA',
#  'C09BB',
#  'C09CA',
#  'C09DA',
#  'C09DB',
#  'C09DX',
#  'C09XA',
#  'C10AA',
#  'C10AB',
#  'C10AC',
#  'C10AD',
#  'C10AX',
#  'C10BA']

# %%
import math
cols_plot = ['C01CA','C02KX','C03CA','C07AB','C07AA','C09AA','C10AX'] 
dfatc_365d = df3[cols_plot].rolling(window=365, center=True).mean()
dfatc_30d = df3[cols_plot].rolling(30, center=True).mean()
dfatc_std = df3[cols_plot].rolling(30, center=True).std()
subplotindex=0
numrows=4
numcols=2
fig, ax = plt.subplots(numrows, numcols, figsize=(18, 12))
plt.subplots_adjust(wspace=0.1, hspace=0.3)
for x in cols_plot:
    rowindex=math.floor(subplotindex/numcols)
    colindex=subplotindex-(rowindex*numcols)
    ax[rowindex,colindex].plot(df3.loc[:,x], linewidth=0.5, label='Daily sales')
    ax[rowindex,colindex].plot(dfatc_30d.loc[:,x], label='30-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_365d.loc[:,x], color='0.2', linewidth=3, label='365-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_std.loc[:,x], color='0.5', linewidth=3, label='30-d Rolling Std')
    ax[rowindex,colindex].set_ylabel('Sales')
    ax[rowindex,colindex].legend()
    ax[rowindex,colindex].set_title('Trends in '+x+' drugs sales');   
    subplotindex=subplotindex+1
plt.show()

# %% [markdown]
# ## level_5

# %%
df4 = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\level_5.csv')
df4.head()
# Out:
#   Row Labels  C01AA05  C01BA01  C01BA02  C01BA03  C01BA13  C01BB01  C01BB02  \
# 0   1/1/2016   1168.0      0.0      0.0    120.0     90.0      0.0    100.0
# 1   1/2/2016    121.0      0.0      0.0    390.0      0.0      0.0      0.0
# 2   1/3/2016   4475.0      0.0      0.0    690.0    300.0      0.0    100.0
# 3   1/4/2016   4209.0      0.0      0.0    810.0    330.0      0.0    100.0
# 4   1/5/2016   3207.0      0.0      0.0    780.0    660.0      0.0    300.0
#
#    C01BC03  C01BC04  ...  C10AB08  C10AC01  C10AC02  C10AD02  C10AX06  \
# 0   7860.0   3390.0  ...    990.0      0.0      0.0      0.0    170.0
# 1   1200.0    660.0  ...    150.0      0.0    100.0      0.0      3.0
# 2  24795.0   8868.0  ...   3510.0     96.0    360.0     90.0    480.0
# 3  25080.0   9273.0  ...   3600.0    120.0    501.0     90.0    447.0
# 4  20010.0   7350.0  ...   3270.0      1.0    350.0    360.0    485.0
#
#    C10AX09  C10AX13  C10AX14  C10AX20  C10BA05
# 0   9480.0      0.0      0.0     11.0      0.0
# 1   1620.0      0.0      0.0      1.0      0.0
# 2  28740.0      0.0      0.0     22.0      0.0
# 3  23685.0      0.0      0.0     18.0      0.0
# 4  23346.0      0.0      0.0     18.0      0.0
#
# [5 rows x 111 columns]

# %%
import math
cols_plot = ['C01CA24','C02KX02','C02KX05','C02KX04','C03CA01','C07AB03','C07AA05','C09AA01','C10AX14','C10AX13'] 
dfatc_365d = df4[cols_plot].rolling(window=365, center=True).mean()
dfatc_30d = df4[cols_plot].rolling(30, center=True).mean()
dfatc_std = df4[cols_plot].rolling(30, center=True).std()
subplotindex=0
numrows=5
numcols=2
fig, ax = plt.subplots(numrows, numcols, figsize=(18, 12))
plt.subplots_adjust(wspace=0.1, hspace=0.4)
for x in cols_plot:
    rowindex=math.floor(subplotindex/numcols)
    colindex=subplotindex-(rowindex*numcols)
    ax[rowindex,colindex].plot(df4.loc[:,x], linewidth=0.5, label='Daily sales')
    ax[rowindex,colindex].plot(dfatc_30d.loc[:,x], label='30-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_365d.loc[:,x], color='0.2', linewidth=3, label='365-d Rolling Mean')
    ax[rowindex,colindex].plot(dfatc_std.loc[:,x], color='0.5', linewidth=3, label='30-d Rolling Std')
    ax[rowindex,colindex].set_ylabel('Sales')
    ax[rowindex,colindex].legend()
    ax[rowindex,colindex].set_title('Trends in '+x+' drugs sales');   
    subplotindex=subplotindex+1
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df4['C10AX14'].rolling(30, center=True).mean().dropna(), freq=365, filt=None)
plt.rcParams["figure.figsize"] = (20,20)
result.plot()
plt.show()

# %%
#df = pd.read_csv('../input/salesweekly.csv')
for x in ['C01','C02','C03','C07','C09','C10']:
    result = seasonal_decompose(df[x], freq=52, model='additive')
    dfs = pd.concat([result.trend, result.seasonal, result.resid, result.observed], axis=1)
    dfs.columns = ['trend', 'seasonal', 'residuals', 'observed']
    dfs=dfs.dropna()
    res=dfs['residuals'].values
    obs=dfs['observed'].values
    resmean=np.mean(np.abs(res))
    obsmean=np.mean(np.abs(obs))
    perc=resmean*100/obsmean
    print(x+' RESMEAN:'+str(resmean)+', OBSMEAN:'+str(obsmean)+', PERC:'+str(perc)+'%')
# Out:
# C01 RESMEAN:20891.16578772211, OBSMEAN:46870.71303841676, PERC:44.571896677993855%
# C02 RESMEAN:25581.179991953308, OBSMEAN:57374.53899883586, PERC:44.58629287195206%
# C03 RESMEAN:51190.33760540408, OBSMEAN:117096.80139697323, PERC:43.71625611861271%
# C07 RESMEAN:136790.56944634512, OBSMEAN:322576.8393480792, PERC:42.40557683025102%
# C09 RESMEAN:210718.69653669835, OBSMEAN:511777.98370197904, PERC:41.173849451758564%
# C10 RESMEAN:198486.70977528027, OBSMEAN:486620.039580908, PERC:40.788848306827454%

# %%
from statsmodels.tsa.stattools import kpss
#warnings.filterwarnings("ignore")
#df=pd.read_csv('../input/salesweekly.csv')
for x in ['C01','C02','C03','C07','C09','C10']:
    print(" > Is "+x+" data stationary ?")
    dftest = kpss(np.log(df[x]), 'ct')
    print("Test statistic = {:.3f}".format(dftest[0]))
    print("P-value = {:.3f}".format(dftest[1]))
    print("Critical values :")
    for k, v in dftest[3].items():
        print("\t{}: {}".format(k, v))
# Out:
#  > Is C01 data stationary ?
# Test statistic = nan
# P-value = nan
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
#  > Is C02 data stationary ?
# Test statistic = nan
# P-value = nan
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
#  > Is C03 data stationary ?
# Test statistic = 0.045
# P-value = 0.100
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
#  > Is C07 data stationary ?
# Test statistic = nan
# P-value = nan
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
#  > Is C09 data stationary ?
# Test statistic = nan
# P-value = nan
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
#  > Is C10 data stationary ?
# Test statistic = 0.070
# P-value = 0.100
# Critical values :
# 	10%: 0.119
# 	5%: 0.146
# 	2.5%: 0.176
# 	1%: 0.216
# C:\Users\DANIEL\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1709: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)
# C:\Users\DANIEL\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1709: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)

# %%
fig, ax = plt.subplots(figsize=(30, 10))
for nm in cols_plot:
    ax.plot(dfatc_365d[nm], label=nm, marker='.', linestyle='-', linewidth=0.5)
    ax.legend()
    ax.set_ylabel('Drug sales')
    ax.set_title('Trends in Drug Sales for different groups (365-d Rolling Means)');
