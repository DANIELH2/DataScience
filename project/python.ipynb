# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.api.types import CategoricalDtype

# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\DANIEL\Documents\DataScience\data\corona1.csv')
df.head()
# Out:
#      Material                 Description  inventory  januarypred  \
# 0  1000000981     TYGACIL VIA 50mg 10X5mL        250            0
# 1  1000001015         KEPPRA TAB 500mg 60     212520            0
# 2  1000001016        KEPPRA TAB 1000mg 60     190920            0
# 3  1000001027         DIATRIM CAP 50mg 30     199980            0
# 4  1000001029  DANALONE SYR 15mg/5mL 60mL       2023         1532
#
#    consumption hadaz ABC consumption.1 seasonality   Volume   price
# 0          120  2.08   C          mean          no   46.900  154.15
# 1        79160  2.68   B          mean          no    6.483    1.69
# 2        56600  3.37   B          mean          no    6.383    3.42
# 3        94410  2.12   C          mean          no    5.467    0.51
# 4         1069  1.89   C          pred         yes  368.000   54.64

# %%
df.shape
# Out:
# (2157, 11)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of         Material                             Description  inventory  \
# 0     1000000981                 TYGACIL VIA 50mg 10X5mL        250
# 1     1000001015                     KEPPRA TAB 500mg 60     212520
# 2     1000001016                    KEPPRA TAB 1000mg 60     190920
# 3     1000001027                     DIATRIM CAP 50mg 30     199980
# 4     1000001029              DANALONE SYR 15mg/5mL 60mL       2023
# 5     1000001039                     KEPPRA TAB 250mg 60      45960
# 6     1000001070                     EXJADE TAB 125mg 28       2072
# 7     1000001071                     EXJADE TAB 500mg 28      13132
# 8     1000001072                     EXJADE TAB 250mg 28       1932
# 9     1000001081                     CRESTOR TAB 20mg 28     384804
# 10    1000001082                     CRESTOR TAB 40mg 28     175252
# 11    1000001083                     CRESTOR TAB 10mg 28     387436
# ...

# %%
df.dtypes
# Out:
# Material           int64
# Description       object
# inventory          int64
# januarypred        int64
# consumption        int64
# hadaz             object
# ABC               object
# consumption.1     object
# seasonality       object
# Volume           float64
# price            float64
# dtype: object

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
prof.to_notebook_iframe()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.4.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df1=df

# %%
df1 = df[['consumption','inventory','januarypred','price','Volume']]

# %%
df1.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001870AFB0470>,
# ...
#       dtype=object)

# %%
df1=df
df1.head()
# Out:
#      Material                 Description  inventory  januarypred  \
# 0  1000000981     TYGACIL VIA 50mg 10X5mL        250            0
# 1  1000001015         KEPPRA TAB 500mg 60     212520            0
# 2  1000001016        KEPPRA TAB 1000mg 60     190920            0
# 3  1000001027         DIATRIM CAP 50mg 30     199980            0
# 4  1000001029  DANALONE SYR 15mg/5mL 60mL       2023         1532
#
#    consumption hadaz ABC consumption.1 seasonality   Volume   price
# 0          120  2.08   C          mean          no   46.900  154.15
# 1        79160  2.68   B          mean          no    6.483    1.69
# 2        56600  3.37   B          mean          no    6.383    3.42
# 3        94410  2.12   C          mean          no    5.467    0.51
# 4         1069  1.89   C          pred         yes  368.000   54.64

# %%
to_log = ['consumption','inventory','januarypred','price','Volume']

# %%
#df1[to_log] = df1[to_log].applymap(lambda x: np.log(x+1)) # add columns log to datafram

# %%
df1.head()
# Out:
#      Material                 Description  inventory  januarypred  \
# 0  1000000981     TYGACIL VIA 50mg 10X5mL   5.525453     0.000000
# 1  1000001015         KEPPRA TAB 500mg 60  12.266796     0.000000
# 2  1000001016        KEPPRA TAB 1000mg 60  12.159615     0.000000
# 3  1000001027         DIATRIM CAP 50mg 30  12.205978     0.000000
# 4  1000001029  DANALONE SYR 15mg/5mL 60mL   7.612831     7.334982
#
#    consumption hadaz ABC consumption.1 seasonality    Volume     price
# 0     4.795791  2.08   C          mean          no  3.869116  5.044392
# 1    11.279239  2.68   B          mean          no  2.012634  0.989541
# 2    10.943782  3.37   B          mean          no  1.999180  1.486140
# 3    11.455413  2.12   C          mean          no  1.866712  0.412110
# 4     6.975414  1.89   C          pred         yes  5.910797  4.018902

# %%
dftoplot = df1[['inventory','januarypred','consumption','Volume','price','ABC','seasonality','hadaz']]

# %%
dftoplot.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018702DC04A8>,
# ...
#       dtype=object)

# %%
sns.pairplot(dftoplot, hue="ABC", height=2.5);

# %%
sns.pairplot(dftoplot, hue="seasonality", height=2.5);

# %%
dftoplot.head()
# Out:
#    inventory  januarypred  consumption    Volume     price ABC seasonality  \
# 0   5.525453     0.000000     4.795791  3.869116  5.044392   C          no
# 1  12.266796     0.000000    11.279239  2.012634  0.989541   B          no
# 2  12.159615     0.000000    10.943782  1.999180  1.486140   B          no
# 3  12.205978     0.000000    11.455413  1.866712  0.412110   C          no
# 4   7.612831     7.334982     6.975414  5.910797  4.018902   C         yes
#
#   hadaz
# 0  2.08
# 1  2.68
# 2  3.37
# 3  2.12
# 4  1.89

# %%
from scipy import stats
def quantile_plot(x, **kwargs):
    qntls, xr = stats.probplot(x, fit=False)
    plt.scatter(xr, qntls, **kwargs)

g = sns.FacetGrid(dftoplot, col="seasonality", height=5)
g.map(quantile_plot, "price");

# %%
sns.pairplot(dftoplot, hue="seasonality", height=2.5);

# %%
sns.set(style="white")
sns.relplot(x="price", y="consumption", hue="ABC",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=dftoplot)
